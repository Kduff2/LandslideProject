# %% [markdown]
# # Term paper code
#
# Use this notebook to run your project code. Submit it before the term paper due date.

# %%
import matplotlib
import pandas as pd
import netCDF4
import dask
import xarray
import geopandas 
import cartopy

# %% [markdown]
# #### Figure 1: Landslides per month

# %%
import pandas as pd
import matplotlib.pyplot as plt

LS = pd.read_csv("nasa_US_landslides.csv")

Months = LS['Months']
Landslides = LS['Landslides per month']
Month_Names = LS['Month_Names']

plt.bar(Months, Landslides)
plt.xticks(Months, labels=Month_Names)
plt.xlabel("Months")
plt.ylabel("Landslide Count")
plt.title("Landslide Count per Month")
# Out:
# Text(0.5, 1.0, 'Landslide Count per Month')

# %% [markdown]
# #### Figure 2: Landslide Fatality count per month

# %%
Months = LS['Months']
Fatalities = LS['Death per month']
Month_Names = LS['Month_Names']

plt.bar(Months, Fatalities)
plt.xticks(Months, labels=Month_Names)
plt.xlabel("Months")
plt.ylabel("Fatality Count")
plt.title("Fatality Count per Month")
# Out:
# Text(0.5, 1.0, 'Fatality Count per Month')

# %% [markdown]
# #### Figure 3: Landslide count per year

# %%
Year = LS['Years']
Landslides = LS['Landslides per year']

plt.bar(Year, Landslides)
plt.xlabel("Years")
plt.ylabel("Landslide Count")
plt.title("Landslide Count per Year")
# Out:
# Text(0.5, 1.0, 'Landslide Count per Year')

# %% [markdown]
# #### Figure 4: Landslide Fatalities per Year

# %%
import matplotlib.pyplot as plt
import pandas as pd 

LS = pd.read_csv("nasa_US_landslides2.csv")

Years = [2005, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
Fatalities =  [3, 4, 1, 8, 1, 2, 1, 15, 48, 9, 6, 11, 25]


plt.bar(Years, Fatalities)
plt.xlabel("Years")
plt.ylabel("Fatality Count")
plt.title("Fatality Count per Year")
# Out:
# Text(0.5, 1.0, 'Fatality Count per Year')

# %% [markdown]
# #### nasa_coolr_reports_point.shp file first 5 rows to show headings

# %%
import geopandas as gpd

landslide_events = gpd.read_file("nasa_coolr_reports_point.shp")

landslide_events.head()
# Out:
#      src_name src_link  ev_id     ev_date ev_time               ev_title  \
# 0  Oregon DOT     None   8113  2015-12-08   15:00     US 30, milepost 95
# 1  Oregon DOT     None   8775  2011-05-27   14:00     OR 501, milepost 6
# 2  Oregon DOT     None   8859  2011-01-06   13:00     OR 42, milepost 44
# 3  Oregon DOT     None   8370  2014-02-18   17:00     OR 281, milepost 5
# 4  Oregon DOT     None   7953  2016-03-25   00:00  OR 180, milepost 13.5
#
#   ev_desc               loc_desc loc_acc     ls_cat  ... latitude longitude  \
# 0    None     US 30, milepost 95   exact  landslide  ...  46.1947 -123.7669
# 1    None     OR 501, milepost 6   exact  landslide  ...  44.3104 -123.6315
# 2    None     OR 42, milepost 44   exact  landslide  ...  42.9627 -123.8388
# 3    None     OR 281, milepost 5   exact  landslide  ...  45.6542 -121.5491
# 4    None  OR 180, milepost 13.5   exact  landslide  ...  44.6452 -123.5804
#
# ...

# %% [markdown]
# #### Figure 5: Map of all events from shapefile

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd

landslide_events = gpd.read_file("nasa_coolr_reports_point.shp")

landslide_events.head()

global_landslides = plt.subplot(1, 1, 1, projection=ccrs.PlateCarree())

global_landslides.add_feature(cfeature.COASTLINE)
global_landslides.add_feature(cfeature.BORDERS)

plt.plot(landslide_events.longitude, landslide_events.latitude, '.', transform=ccrs.PlateCarree())

# %% [markdown]
# #### Firgure 6: Map of landslide events in the US

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd


landslides = plt.subplot(1, 1, 1, projection=ccrs.AlbersEqualArea(central_longitude=-99, central_latitude=35))

landslides.set_extent([-125, -65, 20, 50])

landslides.add_feature(cfeature.COASTLINE)
landslides.add_feature(cfeature.BORDERS)
landslides.add_feature(cfeature.STATES)

landslide_events = gpd.read_file("nasa_coolr_reports_point.shp")
plt.plot(landslide_events.longitude, landslide_events.latitude, '.', transform=ccrs.PlateCarree())
plt.title('US Landslides')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs) -> 'Legend'>

# %% [markdown]
# #### Figure 7: Reading in .nc file

# %%
import netCDF4
import matplotlib.pyplot as plt

precip_data06 = netCDF4.Dataset('precip.V1.0.2006.nc')

precip_data06
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     title: CPC Unified Gauge-Based Analysis of Daily Precipitation over CONUS at PSD
#     Conventions: COARDS
#     description: Gridded daily Precipitation
#     platform: Observations
#     Comments: Preciptation is accumulated from 12z of previous day to 12z of day stored
#     history: originally created V1.0 starting 04/2010 by CAS from data obtained from NCEP/CPC
#  converted to unpacked chunked netCDF4 Aug 2014
#     dataset_title: CPC Unified Gauge-Based Analysis of Daily Precipitation over CONUS
#     References: http://www.psl.noaa.gov/data/gridded/data.unified.daily.conus.html
#     dimensions(sizes): lon(300), lat(120), time(365)
#     variables(dimensions): float32 lat(lat), float32 lon(lon), float64 time(time), float32 precip(time, lat, lon)
#     groups:

# %%
lat = precip_data06.variables['lat'][:]
lon = precip_data06.variables['lon'][:]
time = precip_data06.variables['time'][:]
precip = precip_data06.variables['time'], ['lat'], ['lon']

# %%
plt.contourf(precip_data06['precip'][0,:,:])
plt.colorbar()

# %%
import netCDF4
import matplotlib.pyplot as plt

precip_data = netCDF4.Dataset('precip.V1.0.mon.ltm.1991-2020.nc')

precip_data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: CPC Unified Gauge-Based Analysis of Daily Precipitation over CONUS at PSD: Monthly Values
#     Conventions: COARDS
#     history: Created 2022/11/17 by doMonthLTMNC4
#     description: CPC Unified Gauge-Based Analysis of Daily Precipitation over CONUS at PSD: Gridded Monthly Values. Monthly Values after 2006 are from the real time files (RT)
#     platform: Observations
#     Comments: Preciptation is accumulated from 12z of previous day to 12z of day stored
#     dataset_title: CPC Unified Gauge-Based Analysis of Daily Precipitation over CONUS
#     References: http://www.psl.noaa.gov/data/gridded/data.unified.daily.conus.html
#     not_missing_threshold_percent: minimum 3% values input to have non-missing output value
#     dimensions(sizes): lon(300), lat(120), time(12), nbnds(2)
# ...

# %%
import xarray as xr

data = xr.open_dataset('precip.V1.0.mon.ltm.1991-2020.nc')

data
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/xarray/coding/times.py:987: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/vscode/.local/lib/python3.10/site-packages/xarray/core/indexing.py:524: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# <xarray.Dataset> Size: 3MB
# Dimensions:             (lat: 120, lon: 300, time: 12, nbnds: 2)
# Coordinates:
#   * lat                 (lat) float32 480B 20.12 20.38 20.62 ... 49.62 49.88
#   * lon                 (lon) float32 1kB 230.1 230.4 230.6 ... 304.6 304.9
#   * time                (time) object 96B 0001-01-01 00:00:00 ... 0001-12-01 ...
# ...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Set up the map projection and figure
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.AlbersEqualArea(central_longitude=-99, central_latitude=35))

# Add features to the map
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, edgecolor='black')

# Plot precipitation data
pc = ax.pcolormesh(lon, lat, precip[0, :, :], transform=ccrs.PlateCarree(), cmap='rainbow', shading='auto')

# Add a colorbar
cbar = plt.colorbar(pc, ax=ax, orientation='vertical')
cbar.set_label('Precipitation (mm)')

# Set the title and labels
ax.set_title('Precipitation Map')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

max_precip = precip.max(dim='time')

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.AlbersEqualArea(central_longitude=-99, central_latitude=35))

# Add features to the map
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAKES, edgecolor='black')

# Add the precipitation data
precipitation_plot = max_precip.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='rainbow', 
                                            cbar_kwargs={'label': 'Precipitation (mm)'})

# Set title and labels
ax.set_title('Maximum Precipitation')

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

min_precip = precip.min(dim='time')

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.AlbersEqualArea(central_longitude=-99, central_latitude=35))

# Add features to the map
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAKES, edgecolor='black')

# Add the precipitation data
precipitation_plot = min_precip.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='rainbow', 
                                            cbar_kwargs={'label': 'Precipitation (mm)'})

# Set title and labels
ax.set_title('Minimum Precipitation')

plt.show()
